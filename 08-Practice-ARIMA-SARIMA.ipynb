# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
#import pmdarima as pmd

# %% [markdown]
# ## Exercise
# 1- Look at sensor data that tracks atmospheric $CO_2$ from continuous air samples at Mauna Loa Observatory in Hawaii. This data includes $CO_2$ samples from March 1958 to December 1980.
# - Determine the presence of main trend and seasonality in the data
# - Determine if the data are stationary
# - Split the data in train (90%) and test (10%)
# - Find a set of SARIMAX coordinate models by looking at the ACF and PACF plots.
# - Perform a grid search on the model candidates.
# - Select the best models, based on performance metrics, model complexity, and normality of the residuals.
# - Compare the best model you found with the one from autoarima.

# %%
co2 = pd.read_csv('https://zenodo.org/records/10951538/files/arima_co2.csv?download=1',
                  header = 0,
                  names = ['idx', 'co2'],
                  skipfooter = 2,
                  engine='python')

# convert the column idx into a datetime object and set it as the index
co2['idx'] = pd.to_datetime(co2['idx'])
co2.set_index('idx', inplace=True)

# Rmove the name "idx" from the index column
co2.index.name = None
co2
# Out:
#                co2
# 1965-01-01  319.32
# 1965-02-01  320.36
# 1965-03-01  320.82
# 1965-04-01  322.06
# 1965-05-01  322.17
# ...            ...
# 1980-08-01  337.19
# 1980-09-01  335.49
# 1980-10-01  336.63
# 1980-11-01  337.74
# 1980-12-01  338.36
#
# [192 rows x 1 columns]

# %% [markdown]
# * Tendência crescente
# * Sazonalidade anual

# %%
co2.plot()
# Out:
# <Axes: >

# %%
dcmp = sm.tsa.STL(co2, seasonal=13, period=12).fit()

# %%
dcmp.plot();

# %% [markdown]
# É estacionaria?
# * Tem tendência acentuada --> não estacionária
# * Tem sazonalidade
# * Pelo teste kpss não é estacionária

# %%
sm.tsa.stattools.kpss(co2, nlags='auto')
# Out:
# /var/folders/72/x6_kg98117nd5xkqbx_bl3dc0000gn/T/ipykernel_36908/1581775012.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   sm.tsa.stattools.kpss(co2, nlags='auto')
# (np.float64(1.9852615080853047),
#  np.float64(0.01),
#  9,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Dividir em treino (90%) e teste (10%)

# %%
ts_size = len(co2)
train_size = int(np.round(0.9*ts_size))
train = co2[:train_size]
test = co2[train_size:]

# %%
plt.plot(train, "b", label="train")
plt.plot(test, "r", label="test")
plt.grid(True)

# %%
diff2 = co2.diff(12).diff()
sm.tsa.stattools.kpss(diff2.dropna(), nlags='auto')
# Out:
# /var/folders/72/x6_kg98117nd5xkqbx_bl3dc0000gn/T/ipykernel_36908/1103196873.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   sm.tsa.stattools.kpss(diff2.dropna(), nlags='auto')
# (np.float64(0.05652740701953039),
#  np.float64(0.1),
#  22,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
# encontrar alternativa ao pmd.arima
# ndiffs, nsdiffs = pmd.arima.ndiffs, pmd.arima.nsdiffs
# ndiffs(co2), nsdiffs(co2, 12)
# Out:
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# (1, 1)

# %% [markdown]
# * Find a set of SARIMAX coordinate models by looking at the ACF and PACF plots.
#
# ARIMA
# p, d, q
# 2 1 2
# SARIMA
# P, D, Q
#    1

# %%
fig, axs = plt.subplots(2)
lags = np.r_[1:25]
sm.graphics.tsa.plot_acf(train, lags=lags, ax=axs[0]);
sm.graphics.tsa.plot_pacf(train, lags=lags, ax=axs[1]);
plt.tight_layout()

# %%
fig, axs = plt.subplots(2)
#lags = np.r_[1:25]
sm.graphics.tsa.plot_acf(train.diff(12).diff(1).dropna(), ax=axs[0]);
sm.graphics.tsa.plot_pacf(train.diff(12).diff(1).dropna(), ax=axs[1]);
plt.tight_layout()

# %% [markdown]
# - Perform a grid search on the model candidates.
#
# ARIMA(p, d, q)

# %%
from tqdm import tqdm
import warnings
import itertools
results = []
p, d, q = 2, 1, 2
for (d, p, q) in tqdm(list(itertools.product(range(2), range(3), range(3)))):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        fit = sm.tsa.SARIMAX(np.log(train), order=(p,d,q)).fit()
        result = dict(p=p, d=d, q=q,
                      label=f'ARIMA({p}{d}{q})',
                      AIC=fit.aic, fit=fit)
    results.append(result)
results = pd.DataFrame(results)
# Out:
#   0%|                                                                                                                                                | 0/18 [00:00<?, ?it/s] This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  17%|██████████████████████▋                                                                                                                 | 3/18 [00:00<00:00, 17.36it/s] This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17529D+00    |proj g|=  2.98161D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   2.982D-07   3.175D+00
#   F =   3.1752887108367900
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17529D+00    |proj g|=  9.94037D-01
#
# At iterate    5    f=  2.51063D+00    |proj g|=  1.98279D-02
#
# At iterate   10    f=  2.50064D+00    |proj g|=  3.17600D-04
#
# At iterate   15    f=  2.50002D+00    |proj g|=  6.61881D-04
#
# At iterate   20    f=  2.49995D+00    |proj g|=  2.57208D-05
#
# At iterate   25    f=  2.49994D+00    |proj g|=  7.51355D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     25     31      1     0     0   7.514D-07   2.500D+00
#   F =   2.4999442837756995
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17529D+00    |proj g|=  9.93907D-01
#
# At iterate    5    f=  1.87957D+00    |proj g|=  4.95754D-02
#
# At iterate   10    f=  1.83892D+00    |proj g|=  1.00331D-03
#
# At iterate   15    f=  1.83664D+00    |proj g|=  5.22298D-04
#
# At iterate   20    f=  1.83650D+00    |proj g|=  1.02110D-03
#
# At iterate   25    f=  1.83649D+00    |proj g|=  1.55046D-04
#
# At iterate   30    f=  1.83648D+00    |proj g|=  1.41624D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     30     43      1     0     0   1.416D-05   1.836D+00
#   F =   1.8364843218333446
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.39249D+06    |proj g|=  7.99080D+08
#
# At iterate    5    f=  2.63444D+00    |proj g|=  3.37430D+00
#  This problem is unconstrained.
#  28%|█████████████████████████████████████▊                                                                                                  | 5/18 [00:00<00:00, 13.78it/s] This problem is unconstrained.
#  This problem is unconstrained.
#  39%|████████████████████████████████████████████████████▉                                                                                   | 7/18 [00:00<00:00, 14.35it/s]
# At iterate   10    f= -3.94951D-01    |proj g|=  2.74727D+00
#
# At iterate   15    f= -1.01031D+00    |proj g|=  2.14285D+01
#
# At iterate   20    f= -2.44910D+00    |proj g|=  4.50877D-01
#
# At iterate   25    f= -3.37186D+00    |proj g|=  6.35335D+01
#
# At iterate   30    f= -4.05789D+00    |proj g|=  1.26891D+01
#
# At iterate   35    f= -4.18250D+00    |proj g|=  4.58667D+00
#
# At iterate   40    f= -4.19633D+00    |proj g|=  6.99898D+00
#
# At iterate   45    f= -4.19672D+00    |proj g|=  2.13684D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     47     79      1     0     0   1.444D-05  -4.197D+00
#   F =  -4.1967197577899205
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.99880D+06    |proj g|=  2.52026D+09
#
# At iterate    5    f=  2.81256D+00    |proj g|=  4.08780D+00
#
# At iterate   10    f=  1.32325D+00    |proj g|=  6.03486D-01
#   ys=-2.528E+00  -gs= 1.109E+00 BFGS update SKIPPED
#
# At iterate   15    f= -1.69194D+00    |proj g|=  1.28360D+00
#
# At iterate   20    f= -2.90967D+00    |proj g|=  4.68895D+01
#
# At iterate   25    f= -3.77570D+00    |proj g|=  6.16272D+01
#
# At iterate   30    f= -3.91574D+00    |proj g|=  4.28991D+00
#
# At iterate   35    f= -3.93321D+00    |proj g|=  1.56265D+00
#
# At iterate   40    f= -3.93376D+00    |proj g|=  6.06625D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     42     69      1     1     0   1.644D-03  -3.934D+00
#   F =  -3.9337557813303023
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.86292D+05    |proj g|=  2.81987D+08
#
# At iterate    5    f=  1.47847D+00    |proj g|=  7.06712D-01
#   ys=-1.360E+00  -gs= 1.175E+00 BFGS update SKIPPED
#
# At iterate   10    f= -1.15786D+00    |proj g|=  4.46465D-01
#
# At iterate   15    f= -2.59083D+00    |proj g|=  2.17170D+01
#
# At iterate   20    f= -2.96650D+00    |proj g|=  3.39432D-01
#
# At iterate   25    f= -2.96942D+00    |proj g|=  2.88360D+00
#
# At iterate   30    f= -3.10432D+00    |proj g|=  3.17840D+01
#
# At iterate   35    f= -4.31022D+00    |proj g|=  8.00374D+00
#
# At iterate   40    f= -4.44280D+00    |proj g|=  9.38094D+00
#
# At iterate   45    f= -4.49377D+00    |proj g|=  2.58123D+00
#
# At iterate   50    f= -4.49715D+00    |proj g|=  1.07412D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     97      1     1     0   1.074D-01  -4.497D+00
#   F =  -4.4971474362737798
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.71952D+06    |proj g|=  2.17717D+09
#
# At iterate    5    f=  2.49449D+00    |proj g|=  3.22930D+00
#
# At iterate   10    f=  1.21430D+00    |proj g|=  7.07776D-01
#
# At iterate   15    f= -2.25041D+00    |proj g|=  6.03627D+00
#
# At iterate   20    f= -3.42081D+00    |proj g|=  1.42723D+01
#
# At iterate   25    f= -3.56152D+00    |proj g|=  1.63495D+00
#
# At iterate   30    f= -3.57036D+00    |proj g|=  7.86081D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     30     67      1     0     0   7.861D-01  -3.570D+00
#   F =  -3.5703574357688943
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  50%|████████████████████████████████████████████████████████████████████                                                                    | 9/18 [00:00<00:00, 14.24it/s] This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  83%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                      | 15/18 [00:00<00:00, 25.64it/s] This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.26876D+06    |proj g|=  1.14543D+09
#
# At iterate    5    f=  1.63373D+00    |proj g|=  1.10335D+00
#   ys=-8.067E+00  -gs= 1.233E+00 BFGS update SKIPPED
#
# At iterate   10    f= -1.73604D+00    |proj g|=  2.38939D+00
#
# At iterate   15    f= -3.67212D+00    |proj g|=  6.64832D+01
#
# At iterate   20    f= -4.08707D+00    |proj g|=  7.39690D+01
#
# At iterate   25    f= -4.16873D+00    |proj g|=  1.13225D+01
#
# At iterate   30    f= -4.17434D+00    |proj g|=  3.16596D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33    101      1     1     0   1.363D-01  -4.174D+00
#   F =  -4.1743600770918139
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.65808D+06    |proj g|=  1.36011D+09
#
# At iterate    5    f=  1.97815D+00    |proj g|=  2.06247D+00
#
# At iterate   10    f=  1.04974D+00    |proj g|=  8.63695D-01
#   ys=-7.577E+00  -gs= 1.117E+00 BFGS update SKIPPED
#
# At iterate   15    f= -3.17909D+00    |proj g|=  8.56615D+01
#
# At iterate   20    f= -4.24489D+00    |proj g|=  1.12702D+01
#
# At iterate   25    f= -4.26666D+00    |proj g|=  1.50735D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     25     63      1     1     0   1.507D-01  -4.267D+00
#   F =  -4.2666619735832105
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.21507D+00    |proj g|=  8.36575D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2     17      1     0     0   3.141D-01  -4.215D+00
#   F =  -4.2150802878798110
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.36307D+00    |proj g|=  1.99788D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     25      1     0     0   3.115D-01  -4.364D+00
#   F =  -4.3639836932582137
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.59568D+00    |proj g|=  1.06994D+02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     22      1     0     0   6.197D-01  -4.622D+00
#   F =  -4.6224726552645246
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.55055D+00    |proj g|=  1.90136D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     21      1     0     0   1.901D+00  -4.551D+00
#   F =  -4.5505486927834387
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.60472D+00    |proj g|=  2.93268D+01
#   ys=-2.429E-11  -gs= 4.034E-09 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     39      1     1     0   2.990D-01  -4.606D+00
#   F =  -4.6059264393859429
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.60845D+00    |proj g|=  2.96692D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      3     26      1     0     0   3.211D-01  -4.610D+00
#   F =  -4.6096725230135513
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.66511D+00    |proj g|=  4.62891D+00
#   ys=-7.253E-11  -gs= 1.508E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     70      2     1     0   7.445D-01  -4.665D+00
#   F =  -4.6651151388748531
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 20.98it/s]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.75759D+00    |proj g|=  3.71133D+01
#   ys=-9.750E-12  -gs= 1.092E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      4     29      1     1     0   8.081D-01  -4.759D+00
#   F =  -4.7589993555811274
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.72244D+00    |proj g|=  3.18601D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      2     45      2     0     0   9.118D-01  -4.722D+00
#   F =  -4.7224660529487599
#
# ABNORMAL_TERMINATION_IN_LNSRCH

# %%
results
# Out:
#     p  d  q       label          AIC  \
# 0   0  0  0  ARIMA(000)  1100.649894
# 1   0  0  1  ARIMA(001)   868.980722
# 2   0  0  2  ARIMA(002)   641.423575
# 3   1  0  0  ARIMA(100) -1448.065036
# 4   1  0  1  ARIMA(101) -1355.079500
# 5   1  0  2  ARIMA(102) -1548.013013
# 6   2  0  0  ARIMA(200) -1229.343673
# 7   2  0  1  ARIMA(201) -1436.328587
# 8   2  0  2  ARIMA(202) -1466.265043
# 9   0  1  0  ARIMA(010) -1456.417780
# 10  0  1  1  ARIMA(011) -1505.938358
# 11  0  1  2  ARIMA(012) -1593.375539
# 12  1  1  0  ARIMA(110) -1570.489848
# 13  1  1  1  ARIMA(111) -1587.650548
# 14  1  1  2  ARIMA(112) -1586.946693
# 15  2  1  0  ARIMA(210) -1608.129838
# 16  2  1  1  ARIMA(211) -1638.613777
# 17  2  1  2  ARIMA(212) -1623.973254
#
#                                                   fit
# 0   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 1   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 2   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 3   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 4   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 5   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 6   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 7   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 8   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 9   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 10  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 11  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 12  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 13  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 14  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 15  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 16  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 17  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...

# %%
results.sort_values(by='AIC')#['fit'][6].fittedvalues
# Out:
#     p  d  q       label          AIC  \
# 16  2  1  1  ARIMA(211) -1638.613777
# 17  2  1  2  ARIMA(212) -1623.973254
# 15  2  1  0  ARIMA(210) -1608.129838
# 11  0  1  2  ARIMA(012) -1593.375539
# 13  1  1  1  ARIMA(111) -1587.650548
# 14  1  1  2  ARIMA(112) -1586.946693
# 12  1  1  0  ARIMA(110) -1570.489848
# 5   1  0  2  ARIMA(102) -1548.013013
# 10  0  1  1  ARIMA(011) -1505.938358
# 8   2  0  2  ARIMA(202) -1466.265043
# 9   0  1  0  ARIMA(010) -1456.417780
# 3   1  0  0  ARIMA(100) -1448.065036
# 7   2  0  1  ARIMA(201) -1436.328587
# 4   1  0  1  ARIMA(101) -1355.079500
# 6   2  0  0  ARIMA(200) -1229.343673
# 2   0  0  2  ARIMA(002)   641.423575
# 1   0  0  1  ARIMA(001)   868.980722
# 0   0  0  0  ARIMA(000)  1100.649894
#
#                                                   fit
# 16  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 17  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 15  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 11  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 13  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 14  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 12  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 5   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 10  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 8   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 9   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 3   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 7   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 4   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 6   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 2   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 1   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 0   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...

# %%
forecast = np.exp(results['fit'][16].forecast(19))
sforecast = np.exp(fit.forecast(19))
plt.plot(train, "b", label="train")
plt.plot(test, "r", label="test")
plt.plot(np.exp(results['fit'][16].fittedvalues[1:]), "k", linestyle='--', label='arima')
plt.plot(forecast, "k", linestyle='--', label='arima')
plt.plot(forecast, "orange", linestyle='-.', label='sarima')
plt.grid(True)

# %%
fit = sm.tsa.SARIMAX(np.log(train), order=(2,1,1), seasonal_order=(2,1,1,12)).fit()
# Out:
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -5.01109D+00    |proj g|=  2.32058D+02
#   ys=-8.313E-08  -gs= 5.388E-07 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      5     66      2     1     0   1.203D+01  -5.038D+00
#   F =  -5.0377898710682878
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
fit.fittedvalues
# Out:
# 1965-01-01    0.000000
# 1965-02-01    5.766194
# 1965-03-01    5.769445
# 1965-04-01    5.770880
# 1965-05-01    5.774738
#                 ...
# 1979-01-01    5.816918
# 1979-02-01    5.818360
# 1979-03-01    5.821934
# 1979-04-01    5.825464
# 1979-05-01    5.826079
# Length: 173, dtype: float64

# %%
t_df = train[1:].copy()
fitted_df = np.exp(results['fit'][16].fittedvalues[1:]).copy()

# %%
fitted_df
# Out:
# 1965-02-01    319.320000
# 1965-03-01    321.156107
# 1965-04-01    320.790292
# 1965-05-01    322.894022
# 1965-06-01    321.747219
#                  ...
# 1979-01-01    335.912583
# 1979-02-01    336.695093
# 1979-03-01    336.521026
# 1979-04-01    338.256403
# 1979-05-01    338.756457
# Length: 172, dtype: float64

# %%
sforecast = np.exp(fit.forecast(19))
plt.plot(train, "b", label="train")
plt.plot(test, "r", label="test")
plt.plot(fitted_df, "k", linestyle='--', label='sarima')
#plt.plot(forecast, "k", linestyle='--', label='arima')
plt.plot(sforecast, "orange", linestyle='-.', label='sarima')
plt.grid(True)

# %%
results
# Out:
#     p  d  q       label          AIC  \
# 0   0  0  0  ARIMA(000)  1100.649894
# 1   0  0  1  ARIMA(001)   868.980722
# 2   0  0  2  ARIMA(002)   641.423575
# 3   1  0  0  ARIMA(100) -1448.065036
# 4   1  0  1  ARIMA(101) -1355.079500
# 5   1  0  2  ARIMA(102) -1548.013013
# 6   2  0  0  ARIMA(200) -1229.343673
# 7   2  0  1  ARIMA(201) -1436.328587
# 8   2  0  2  ARIMA(202) -1466.265043
# 9   0  1  0  ARIMA(010) -1456.417780
# 10  0  1  1  ARIMA(011) -1505.938358
# 11  0  1  2  ARIMA(012) -1593.375539
# 12  1  1  0  ARIMA(110) -1570.489848
# 13  1  1  1  ARIMA(111) -1587.650548
# 14  1  1  2  ARIMA(112) -1586.946693
# 15  2  1  0  ARIMA(210) -1608.129838
# 16  2  1  1  ARIMA(211) -1638.613777
# 17  2  1  2  ARIMA(212) -1623.973254
#
#                                                   fit
# 0   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 1   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 2   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 3   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 4   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 5   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 6   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 7   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 8   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 9   <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 10  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 11  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 12  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 13  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 14  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 15  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 16  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...
# 17  <statsmodels.tsa.statespace.sarimax.SARIMAXRes...

# %%
fit_auto = pmd.auto_arima(
    train,
    seasonal=True,
    suppress_warnings=True,
    error_action='ignore',
    trace=True
)
# Out:
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=535.598, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=422.112, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=438.474, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=535.348, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=383.493, Time=0.02 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=365.570, Time=0.02 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=367.196, Time=0.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=365.025, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=382.369, Time=0.01 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=366.766, Time=0.02 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=343.379, Time=0.03 sec
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=341.673, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=402.819, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=343.359, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=420.537, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=387.200, Time=0.02 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=344.802, Time=0.05 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 0.818 seconds
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/gabrielasoares/.local/share/virtualenvs/times_series-ymuiMkMa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
